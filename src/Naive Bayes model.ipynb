# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
moviesData = pd.read_csv('CleanedDatasetForML.csv')

# %%
moviesData.head(10)
# Out:
#    Unnamed: 0                            Title Selected_Genre  \
# 0           6          The Great Train Robbery         action
# 1           7                  The Suburbanite         comedy
# 2          13                     Daniel Boone      biography
# 3          14  How Brown Saw the Baseball Game         comedy
# 4          15                     Laughing Gas         comedy
# 5          16         The Adventures of Dollie          drama
# 6          17                  The Black Viper          drama
# 7          18           A Calamitous Elopement         comedy
# 8          19             The Call of the Wild         action
# 9          20                A Christmas Carol          drama
#
#                                           Clean_Plot
# 0  the film opens with two bandits breaking into ...
# 1  the film is about a family who move to the sub...
# 2  boone  daughter befriends an indian maiden as ...
# 3  before heading out to a baseball game at a nea...
# 4  the plot is that of a black woman going to the...
# 5  on a beautiful summer day a father and mother ...
# 6  a thug accosts a girl as she leaves her workpl...
# 7  a young couple decides to elope after being ca...
# 8  a white girl (florence lawrence) rejects a pro...
# 9  no prints of the first american film adaptatio...

# %%
moviesData['Split_Genre']=moviesData['Selected_Genre'].str.split('|')
moviesData['Split_Genre']= moviesData['Split_Genre'].apply(np.sort).apply(np.unique)

# %%
moviesData.head(50)
# Out:
#     Unnamed: 0                                     Title  Selected_Genre  \
# 0            6                   The Great Train Robbery          action
# 1            7                           The Suburbanite          comedy
# 2           13                              Daniel Boone       biography
# 3           14           How Brown Saw the Baseball Game          comedy
# 4           15                              Laughing Gas          comedy
# 5           16                  The Adventures of Dollie           drama
# 6           17                           The Black Viper           drama
# 7           18                    A Calamitous Elopement          comedy
# 8           19                      The Call of the Wild          action
# 9           20                         A Christmas Carol           drama
# 10          21                     The Fight for Freedom          action
# 11          22                              At the Altar           drama
# 12          23                  A Drunkard's Reformation           drama
# 13          24                          The Golden Louis           drama
# 14          26                          An Arcadian Maid           drama
# 15          29               Hemlock Hoax, the Detective          comedy
# 16          30            The House with Closed Shutters           drama
# 17          31                    A Lad from Old Ireland           drama
# 18          33                                    Ramona           drama
# 19          37  The Black Arrow: A Tale of the Two Roses           drama
# 20          38                          Brown of Harvard           drama
# 21          40                         David Copperfield           drama
# 22          42                            Sweet Memories           drama
# 23          44                   Dr. Jekyll and Mr. Hyde        thriller
# 24          46               The Musketeers of Pig Alley           drama
# 25          48                            Petticoat Camp          comedy
# 26          49                 Put Yourself in His Place           drama
# 27          52         Barney Oldfield's Race for a Life          comedy
# 28          53                                Bob's Baby          comedy
# 29          54                      Cohen Saves the Flag          comedy
# 30          55                   Dr. Jekyll and Mr. Hyde        thriller
# 31          56                  The Evidence of the Film           crime
# 32          57                    The Face at the Window           drama
# 33          58                             The Quakeress           drama
# 34          59                       The Restless Spirit           drama
# 35          60           The Telephone Girl and the Lady           drama
# 36          61                   The Avenging Conscience  drama|thriller
# 37          62                   The Battle of the Sexes           drama
# 38          64                       Brewster's Millions          comedy
# 39          65                                A Busy Day          comedy
# 40          66                     The Call of the North          action
# 41          68                       Caught in a Cabaret          comedy
# 42          69                        Caught in the Rain          comedy
# 43          71                         Cruel, Cruel Love          comedy
# 44          72                        Dough and Dynamite          comedy
# 45          73                                The Escape           drama
# 46          76                        Gentlemen of Nerve          comedy
# 47          77                        Getting Acquainted          comedy
# 48          78                        His Father's Rifle           drama
# 49          81                          Home, Sweet Home       biography
#
#                                            Clean_Plot        Split_Genre
# 0   the film opens with two bandits breaking into ...           [action]
# 1   the film is about a family who move to the sub...           [comedy]
# 2   boone  daughter befriends an indian maiden as ...        [biography]
# 3   before heading out to a baseball game at a nea...           [comedy]
# 4   the plot is that of a black woman going to the...           [comedy]
# 5   on a beautiful summer day a father and mother ...            [drama]
# 6   a thug accosts a girl as she leaves her workpl...            [drama]
# 7   a young couple decides to elope after being ca...           [comedy]
# 8   a white girl (florence lawrence) rejects a pro...           [action]
# 9   no prints of the first american film adaptatio...            [drama]
# 10  the film opens in a town on the mexican border...           [action]
# 11  a rejected admirer sets up a trap to kill his ...            [drama]
# 12  john wharton, the husband of a true and trusti...            [drama]
# 13  an old woman sends a girl begging in the stree...            [drama]
# 14  mary pickford plays priscilla an unemployed ma...            [drama]
# 15  hemlock hoax is a detective who has little res...           [comedy]
# 16  during the american civil war a young soldier ...            [drama]
# 17  an irish boy (olcott) emigrates to america to ...            [drama]
# 18  ramona chronicles the romance between ramona (...            [drama]
# 19  the novel is set in the reign of "old king hen...            [drama]
# 20  the story deals with tom brown  efforts to sav...            [drama]
# 21  "david copperfield consists of three reels and...            [drama]
# 22  polly biblett (mary pickford), a young lady, t...            [drama]
# 23  white-haired dr. jekyll has secretly locked hi...         [thriller]
# 24  the film is about a poor married couple living...            [drama]
# 25  only lasting 15 minutes, it is a light-hearted...           [comedy]
# 26  the story is of an english manufacturing town ...            [drama]
# 27  barney oldfield races a speeding locomotive to...           [comedy]
# 28  bob, a typically devoted husband, is told by h...           [comedy]
# 29  cohen (ford sterling) and his rival goldberg (...           [comedy]
# 30  dr. henry jekyll (king baggot) sends a note to...         [thriller]
# 31  the evidence of the film tells the story of a ...            [crime]
# 32  as described in a 1913 blurb: "the foreman of ...            [drama]
# 33  the setting is an early american village, wher...            [drama]
# 34  the film begins with the dreamer, a restless a...            [drama]
# 35  a telephone operator is walking out with a han...            [drama]
# 36  a young man (henry b. walthall) falls in love ...  [drama, thriller]
# 37  frank andrews (donald crisp) is a well-to-do, ...            [drama]
# 38  wealthy edwin peter brewster disowns his son r...           [comedy]
# 39  in a busy day, a wife (played by an energetic ...           [comedy]
# 40  graehme, ned stewart  father was accused of ad...           [action]
# 41  chaplin plays a waiter who fakes being a greek...           [comedy]
# 42  the action starts in a park, where a man is tr...           [comedy]
# 43  chaplin plays a character quite different from...           [comedy]
# 44  the story involves chaplin and chester conklin...           [comedy]
# 45  the film begins with a short prologue explaini...            [drama]
# 46  mabel and her beau go to an auto race and are ...           [comedy]
# 47  in one of chaplin  "park comedies" for keyston...           [comedy]
# 48  james birch, an english hunter, is accidentall...            [drama]
# 49  john howard payne leaves home and begins a car...        [biography]

# %%
moviesData = pd.concat([moviesData, moviesData.Split_Genre.apply(lambda x: '-'.join(x)).str.get_dummies(sep='-')], axis=1)
trainData, testData = train_test_split(moviesData, random_state=0, test_size=0.20, shuffle=True)

# %%
tfidf = TfidfVectorizer(stop_words ='english', smooth_idf=False, sublinear_tf=False, norm=None, analyzer='word')

# %%
x_train = tfidf.fit_transform(trainData.Clean_Plot) 
x_test  = tfidf.transform(testData.Clean_Plot)

# %%
y_train = trainData[trainData.columns[4:]]
y_test = testData[testData.columns[4:]]

# %%
y_train.head(50)
# Out:
#            Split_Genre  action  animation  biography  black  children  comedy  \
# 19824          [drama]       0          0          0      0         0       0
# 16969         [comedy]       0          0          0      0         0       1
# 23041         [action]       1          0          0      0         0       0
# 865           [action]       1          0          0      0         0       0
# 23297          [drama]       0          0          0      0         0       0
# 4109           [drama]       0          0          0      0         0       0
# 11468          [drama]       0          0          0      0         0       0
# 3199          [action]       1          0          0      0         0       0
# 10784         [action]       1          0          0      0         0       0
# 19407          [drama]       0          0          0      0         0       0
# 24709         [action]       1          0          0      0         0       0
# 18462         [action]       1          0          0      0         0       0
# 20668         [action]       1          0          0      0         0       0
# 16222          [drama]       0          0          0      0         0       0
# 3354         [mystery]       0          0          0      0         0       0
# 6740       [animation]       0          1          0      0         0       0
# 7552        [thriller]       0          0          0      0         0       0
# 18206         [action]       1          0          0      0         0       0
# 17022          [drama]       0          0          0      0         0       0
# 16914         [comedy]       0          0          0      0         0       1
# 6122           [drama]       0          0          0      0         0       0
# 1727           [drama]       0          0          0      0         0       0
# 10423          [drama]       0          0          0      0         0       0
# 3012          [action]       1          0          0      0         0       0
# 22521          [crime]       0          0          0      0         0       0
# 22040  [comedy, drama]       0          0          0      0         0       1
# 11759          [drama]       0          0          0      0         0       0
# 461            [drama]       0          0          0      0         0       0
# 2813          [comedy]       0          0          0      0         0       1
# 8148           [drama]       0          0          0      0         0       0
# 7382           [drama]       0          0          0      0         0       0
# 15764          [drama]       0          0          0      0         0       0
# 10220          [drama]       0          0          0      0         0       0
# 12684          [crime]       0          0          0      0         0       0
# 20484          [drama]       0          0          0      0         0       0
# 11015         [comedy]       0          0          0      0         0       1
# 17362          [crime]       0          0          0      0         0       0
# 24356       [thriller]       0          0          0      0         0       0
# 20083  [comedy, drama]       0          0          0      0         0       1
# 5503          [action]       1          0          0      0         0       0
# 15640  [comedy, drama]       0          0          0      0         0       1
# 20397       [thriller]       0          0          0      0         0       0
# 22726         [comedy]       0          0          0      0         0       1
# 19988          [crime]       0          0          0      0         0       0
# 7800           [drama]       0          0          0      0         0       0
# 25056          [drama]       0          0          0      0         0       0
# 10033       [thriller]       0          0          0      0         0       0
# 19838        [history]       0          0          0      0         0       0
# 4653          [action]       1          0          0      0         0       0
# 1623          [comedy]       0          0          0      0         0       1
#
#        crime  documentary  drama  fantasy  fiction  history  musical  mystery  \
# 19824      0            0      1        0        0        0        0        0
# 16969      0            0      0        0        0        0        0        0
# 23041      0            0      0        0        0        0        0        0
# 865        0            0      0        0        0        0        0        0
# 23297      0            0      1        0        0        0        0        0
# 4109       0            0      1        0        0        0        0        0
# 11468      0            0      1        0        0        0        0        0
# 3199       0            0      0        0        0        0        0        0
# 10784      0            0      0        0        0        0        0        0
# 19407      0            0      1        0        0        0        0        0
# 24709      0            0      0        0        0        0        0        0
# 18462      0            0      0        0        0        0        0        0
# 20668      0            0      0        0        0        0        0        0
# 16222      0            0      1        0        0        0        0        0
# 3354       0            0      0        0        0        0        0        1
# 6740       0            0      0        0        0        0        0        0
# 7552       0            0      0        0        0        0        0        0
# 18206      0            0      0        0        0        0        0        0
# 17022      0            0      1        0        0        0        0        0
# 16914      0            0      0        0        0        0        0        0
# 6122       0            0      1        0        0        0        0        0
# 1727       0            0      1        0        0        0        0        0
# 10423      0            0      1        0        0        0        0        0
# 3012       0            0      0        0        0        0        0        0
# 22521      1            0      0        0        0        0        0        0
# 22040      0            0      1        0        0        0        0        0
# 11759      0            0      1        0        0        0        0        0
# 461        0            0      1        0        0        0        0        0
# 2813       0            0      0        0        0        0        0        0
# 8148       0            0      1        0        0        0        0        0
# 7382       0            0      1        0        0        0        0        0
# 15764      0            0      1        0        0        0        0        0
# 10220      0            0      1        0        0        0        0        0
# 12684      1            0      0        0        0        0        0        0
# 20484      0            0      1        0        0        0        0        0
# 11015      0            0      0        0        0        0        0        0
# 17362      1            0      0        0        0        0        0        0
# 24356      0            0      0        0        0        0        0        0
# 20083      0            0      1        0        0        0        0        0
# 5503       0            0      0        0        0        0        0        0
# 15640      0            0      1        0        0        0        0        0
# 20397      0            0      0        0        0        0        0        0
# 22726      0            0      0        0        0        0        0        0
# 19988      1            0      0        0        0        0        0        0
# 7800       0            0      1        0        0        0        0        0
# 25056      0            0      1        0        0        0        0        0
# 10033      0            0      0        0        0        0        0        0
# 19838      0            0      0        0        0        1        0        0
# 4653       0            0      0        0        0        0        0        0
# 1623       0            0      0        0        0        0        0        0
#
#        romance  science  series  thriller
# 19824        0        0       0         0
# 16969        0        0       0         0
# 23041        0        0       0         0
# 865          0        0       0         0
# 23297        0        0       0         0
# 4109         0        0       0         0
# 11468        0        0       0         0
# 3199         0        0       0         0
# 10784        0        0       0         0
# 19407        0        0       0         0
# 24709        0        0       0         0
# 18462        0        0       0         0
# 20668        0        0       0         0
# 16222        0        0       0         0
# 3354         0        0       0         0
# 6740         0        0       0         0
# 7552         0        0       0         1
# 18206        0        0       0         0
# 17022        0        0       0         0
# 16914        0        0       0         0
# 6122         0        0       0         0
# 1727         0        0       0         0
# 10423        0        0       0         0
# 3012         0        0       0         0
# 22521        0        0       0         0
# 22040        0        0       0         0
# 11759        0        0       0         0
# 461          0        0       0         0
# 2813         0        0       0         0
# 8148         0        0       0         0
# 7382         0        0       0         0
# 15764        0        0       0         0
# 10220        0        0       0         0
# 12684        0        0       0         0
# 20484        0        0       0         0
# 11015        0        0       0         0
# 17362        0        0       0         0
# 24356        0        0       0         1
# 20083        0        0       0         0
# 5503         0        0       0         0
# 15640        0        0       0         0
# 20397        0        0       0         1
# 22726        0        0       0         0
# 19988        0        0       0         0
# 7800         0        0       0         0
# 25056        0        0       0         0
# 10033        0        0       0         1
# 19838        0        0       0         0
# 4653         0        0       0         0
# 1623         0        0       0         0

# %%
categories = np.array(y_train.columns[1:])

# %%
categories
# Out:
# array(['action', 'animation', 'biography', 'black', 'children', 'comedy',
#        'crime', 'documentary', 'drama', 'fantasy', 'fiction', 'history',
#        'musical', 'mystery', 'romance', 'science', 'series', 'thriller'],
#       dtype=object)

# %%
model = MultinomialNB(fit_prior=True, class_prior=None)
naiveBayes = pd.DataFrame(columns=['Genre', 'accuracy'])

# %%
i = 0
for genre in categories:
    model.fit(x_train, y_train[genre])
    pred = model.predict(x_test)
    print("GENRE: " + genre)
    print('')
    print('cross validation....')
    scores = cross_val_score(model, x_train, y_train[genre], cv=5)
    print(scores)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    print('')
    print('confusion matrix')
    print(confusion_matrix(y_test[genre], pred))
    print('')
    print(classification_report(y_test[genre], pred))
    naiveBayes.loc[i,'Genre'] = genre
    naiveBayes.loc[i,'accuracy'] = accuracy_score(y_test[genre], pred)
    i=i+1
# Out:
# GENRE: action
#
# cross validation....
# [0.78521653 0.79263132 0.79337814 0.78366941 0.79213343]
# Accuracy: 0.79 (+/- 0.01)
#
# confusion matrix
# [[3822  407]
#  [ 292  501]]
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      4229
#            1       0.55      0.63      0.59       793
#
#     accuracy                           0.86      5022
#    macro avg       0.74      0.77      0.75      5022
# weighted avg       0.87      0.86      0.86      5022
#
# GENRE: animation
#
# cross validation....
# [0.92956695 0.92730894 0.92631317 0.93203883 0.93029624]
# Accuracy: 0.93 (+/- 0.00)
#
# confusion matrix
# [[4822   47]
#  [  62   91]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4869
#            1       0.66      0.59      0.63       153
#
#     accuracy                           0.98      5022
#    macro avg       0.82      0.79      0.81      5022
# weighted avg       0.98      0.98      0.98      5022
#
# GENRE: biography
#
# cross validation....
# [0.84221005 0.85660941 0.85113269 0.85810306 0.85461787]
# Accuracy: 0.85 (+/- 0.01)
#
# confusion matrix
# [[4891   68]
#  [  49   14]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4959
#            1       0.17      0.22      0.19        63
#
#     accuracy                           0.98      5022
#    macro avg       0.58      0.60      0.59      5022
# weighted avg       0.98      0.98      0.98      5022
#
# GENRE: black
#
# cross validation....
# [0.83474365 0.84739856 0.84192183 0.83793876 0.84117501]
# Accuracy: 0.84 (+/- 0.01)
#
# confusion matrix
# [[4846  110]
#  [  49   17]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      4956
#            1       0.13      0.26      0.18        66
#
#     accuracy                           0.97      5022
#    macro avg       0.56      0.62      0.58      5022
# weighted avg       0.98      0.97      0.97      5022
#
# GENRE: children
#
# cross validation....
# [0.83549029 0.85312422 0.85411999 0.85909883 0.85113269]
# Accuracy: 0.85 (+/- 0.02)
#
# confusion matrix
# [[4867   81]
#  [  61   13]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      4948
#            1       0.14      0.18      0.15        74
#
#     accuracy                           0.97      5022
#    macro avg       0.56      0.58      0.57      5022
# weighted avg       0.98      0.97      0.97      5022
#
# GENRE: comedy
#
# cross validation....
# [0.68740667 0.69081404 0.68707991 0.69156087 0.69255663]
# Accuracy: 0.69 (+/- 0.00)
#
# confusion matrix
# [[2978  827]
#  [ 416  801]]
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83      3805
#            1       0.49      0.66      0.56      1217
#
#     accuracy                           0.75      5022
#    macro avg       0.68      0.72      0.70      5022
# weighted avg       0.78      0.75      0.76      5022
#
# GENRE: crime
#
# cross validation....
# [0.81657541 0.81279562 0.82300224 0.8180234  0.82125965]
# Accuracy: 0.82 (+/- 0.01)
#
# confusion matrix
# [[4500  247]
#  [ 153  122]]
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      4747
#            1       0.33      0.44      0.38       275
#
#     accuracy                           0.92      5022
#    macro avg       0.65      0.70      0.67      5022
# weighted avg       0.93      0.92      0.93      5022
#
# GENRE: documentary
#
# cross validation....
# [0.91413639 0.91909385 0.92158327 0.92208116 0.91610655]
# Accuracy: 0.92 (+/- 0.01)
#
# confusion matrix
# [[4984   16]
#  [  17    5]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5000
#            1       0.24      0.23      0.23        22
#
#     accuracy                           0.99      5022
#    macro avg       0.62      0.61      0.61      5022
# weighted avg       0.99      0.99      0.99      5022
#
# GENRE: drama
#
# cross validation....
# [0.64385266 0.65123226 0.63878516 0.63853622 0.63704257]
# Accuracy: 0.64 (+/- 0.01)
#
# confusion matrix
# [[2759  893]
#  [ 584  786]]
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79      3652
#            1       0.47      0.57      0.52      1370
#
#     accuracy                           0.71      5022
#    macro avg       0.65      0.66      0.65      5022
# weighted avg       0.73      0.71      0.71      5022
#
# GENRE: fantasy
#
# cross validation....
# [0.88725734 0.89967638 0.89768484 0.8974359  0.89494648]
# Accuracy: 0.90 (+/- 0.01)
#
# confusion matrix
# [[4941   46]
#  [  29    6]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4987
#            1       0.12      0.17      0.14        35
#
#     accuracy                           0.99      5022
#    macro avg       0.55      0.58      0.57      5022
# weighted avg       0.99      0.99      0.99      5022
#
# GENRE: fiction
#
# cross validation....
# [0.90467894 0.90141897 0.90316156 0.89668907 0.89469754]
# Accuracy: 0.90 (+/- 0.01)
#
# confusion matrix
# [[4792   86]
#  [  48   96]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      4878
#            1       0.53      0.67      0.59       144
#
#     accuracy                           0.97      5022
#    macro avg       0.76      0.82      0.79      5022
# weighted avg       0.98      0.97      0.97      5022
#
# GENRE: history
#
# cross validation....
# [0.91463415 0.92730894 0.9223301  0.92033856 0.92730894]
# Accuracy: 0.92 (+/- 0.01)
#
# confusion matrix
# [[4989   11]
#  [  20    2]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5000
#            1       0.15      0.09      0.11        22
#
#     accuracy                           0.99      5022
#    macro avg       0.57      0.54      0.56      5022
# weighted avg       0.99      0.99      0.99      5022
#
# GENRE: musical
#
# cross validation....
# [0.80861125 0.81777446 0.81304456 0.83644511 0.8210107 ]
# Accuracy: 0.82 (+/- 0.02)
#
# confusion matrix
# [[4667  205]
#  [  85   65]]
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      4872
#            1       0.24      0.43      0.31       150
#
#     accuracy                           0.94      5022
#    macro avg       0.61      0.70      0.64      5022
# weighted avg       0.96      0.94      0.95      5022
#
# GENRE: mystery
#
# cross validation....
# [0.8628671  0.87303958 0.87602689 0.86806074 0.87478218]
# Accuracy: 0.87 (+/- 0.01)
#
# confusion matrix
# [[4904   54]
#  [  40   24]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4958
#            1       0.31      0.38      0.34        64
#
#     accuracy                           0.98      5022
#    macro avg       0.65      0.68      0.66      5022
# weighted avg       0.98      0.98      0.98      5022
#
# GENRE: romance
#
# cross validation....
# [0.77899452 0.79088872 0.76947971 0.78864824 0.78914613]
# Accuracy: 0.78 (+/- 0.02)
#
# confusion matrix
# [[4055  567]
#  [ 187  213]]
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.91      4622
#            1       0.27      0.53      0.36       400
#
#     accuracy                           0.85      5022
#    macro avg       0.61      0.70      0.64      5022
# weighted avg       0.90      0.85      0.87      5022
#
# GENRE: science
#
# cross validation....
# [0.90467894 0.90141897 0.90316156 0.89668907 0.89469754]
# Accuracy: 0.90 (+/- 0.01)
#
# confusion matrix
# [[4792   86]
#  [  48   96]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      4878
#            1       0.53      0.67      0.59       144
#
#     accuracy                           0.97      5022
#    macro avg       0.76      0.82      0.79      5022
# weighted avg       0.98      0.97      0.97      5022
#
# GENRE: series
#
# cross validation....
# [0.94499751 0.94772218 0.9472243  0.94423699 0.94896689]
# Accuracy: 0.95 (+/- 0.00)
#
# confusion matrix
# [[5007    3]
#  [   8    4]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5010
#            1       0.57      0.33      0.42        12
#
#     accuracy                           1.00      5022
#    macro avg       0.78      0.67      0.71      5022
# weighted avg       1.00      1.00      1.00      5022
#
# GENRE: thriller
#
# cross validation....
# [0.82553509 0.82798108 0.8210107  0.81528504 0.82798108]
# Accuracy: 0.82 (+/- 0.01)
#
# confusion matrix
# [[4246  251]
#  [ 251  274]]
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4497
#            1       0.52      0.52      0.52       525
#
#     accuracy                           0.90      5022
#    macro avg       0.73      0.73      0.73      5022
# weighted avg       0.90      0.90      0.90      5022

# %%
naiveBayes.to_csv('NaiveBayesModelAccuracy.csv',sep=',')

# %%
naiveBayes
# Out:
#           Genre  accuracy
# 0        action  0.860812
# 1     animation  0.978295
# 2     biography  0.976703
# 3         black  0.968339
# 4      children  0.971724
# 5        comedy  0.752489
# 6         crime   0.92035
# 7   documentary  0.993429
# 8         drama  0.705894
# 9       fantasy  0.985066
# 10      fiction  0.973317
# 11      history  0.993827
# 12      musical  0.942254
# 13      mystery  0.981282
# 14      romance  0.849861
# 15      science  0.973317
# 16       series   0.99781
# 17     thriller   0.90004
